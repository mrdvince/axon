# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('road.jpg')
## convert to rgb
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
height = img.shape[0]
width = img.shape[1]
plt.imshow(img)
plt.show()

# %%
roi_interest_rate = [
    (0, height),
    (width/2, height/2),
    width, height

]
